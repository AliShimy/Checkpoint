# %% [markdown]
# # Rectify the code in each cell and **explain the error in comments**

# %% [markdown]
# ### index error

# %%
mylist=[14, "hello", 967]
mylist=[6]
#trying to access an item at an invalid index.

# %%
import pandas
import numpy
#a specified function can not be found.

# %% [markdown]
# # syntax error

# %%
print("python errors")
#name and syntax error
# Out:
# python errors

# %% [markdown]
# # key error

# %%
mydictionnary={True:"hello",False:"bye", '3':"python"}
mydictionnary[True]
#a key is not found.
# Out:
# 'hello'

# %% [markdown]
# # indentation error

# %%
i=14
while i<78:
  print(i)
i+=1
#an incorrect indentation is occured.
# Out:
# Streaming output truncated to the last 5000 lines.
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# ...

# %% [markdown]
# # StopIteration

# %%
it=iter([1,2,3])
next(it)
next(it)
next(it)
#next() function goes beyond the iterator items.
# Out:
# 3

# %% [markdown]
# # TypeError

# %%
15+15
#an operation or function is applied to an object of an inappropriate type.
# Out:
# 30

# %% [markdown]
# # ValueError

# %%
int('21')
#a function's argument is of an inappropriate type.
# Out:
# 21

# %% [markdown]
# # NameError

# %%
lang = "python"
#an object could not be found.

# %% [markdown]
# # ZeroDivisionError

# %%
x=19/1
#the second operator in the division is zero.
